# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaFathimas/DashBoards/blob/main/wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Hierarchical Clustering Dendrogram**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
data=pd.read_csv("wine.csv")
data.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
data_subset = data[['Alcohol', 'Malic.acid']]
print(data_subset)
# Out:
#      Alcohol  Malic.acid
# 0      14.23        1.71
# 1      13.20        1.78
# 2      13.16        2.36
# 3      14.37        1.95
# 4      13.24        2.59
# ..       ...         ...
# 173    13.71        5.65
# 174    13.40        3.91
# 175    13.27        4.28
# 176    13.17        2.59
# 177    14.13        4.10
#
# [178 rows x 2 columns]

# %%
linked=linkage(data,method='single')

# %%
plt.figure(figsize=(12, 6))
dendrogram(linked,
           orientation='top',
           distance_sort='ascending',
           show_leaf_counts=False,
           truncate_mode='lastp',
           p=30)
plt.title("Hierarchical Clustering Dendrogram (wine Dataset)")
plt.xlabel("Sample index or cluster size")
plt.ylabel("Distance")
plt.show()
